# %% [markdown]
# ## import

# %%
import cv2
import matplotlib.pyplot as plt

from inferencia.task.object_detection.object_detection_2d.object_detection_2d_manager import ObjectDetection2DManager

# %% [markdown]
# ## constant

# %%
model_name = "TinyYoloV4"
vis_name = "BBOXVisualizer"

# %%
image_path = '/workspace/data/dog.jpg'

# %% [markdown]
# ## model

# %%
model = ObjectDetection2DManager.get_model(model_name)
visualizer = ObjectDetection2DManager.get_visualizer()
# Out:
# 2021/07/04 23:39:25.310    INFO
# =====================
#  Initialize ObjectDetection2D-YoloV4-TinyYoloV4
# =====================
#  [YoloV4  MainProcess - MainThread]
# 2021/07/04 23:39:26.332    INFO Initial inference [YoloV4  MainProcess - MainThread]

# %% [markdown]
# ## data

# %%
image = cv2.imread(image_path)

# %%
plt.imshow(image[:,:,::-1])
plt.show()

# %% [markdown]
# ## inference

# %%
# %time object_detection_results = model.inference(image)
# Out:
# CPU times: user 12.4 ms, sys: 1.95 ms, total: 14.3 ms
# Wall time: 8.21 ms

# %%
object_detection_results
# Out:
# [ObjectDetection2DResult(class_id=1, class_name='bicycle', xmin=71, ymin=99, xmax=576, ymax=479, confidence=0.605963),
#  ObjectDetection2DResult(class_id=7, class_name='truck', xmin=464, ymin=79, xmax=704, ymax=170, confidence=0.8147336),
#  ObjectDetection2DResult(class_id=16, class_name='dog', xmin=136, ymin=205, xmax=319, ymax=541, confidence=0.87032294)]

# %% [markdown]
# ## visualize

# %%
vis_image = visualizer.visualize(image, object_detection_results)

# %%
plt.imshow(vis_image[:,:,::-1])
plt.show()
