# %% [markdown]
# # import

# %%
import cv2
import matplotlib.pyplot as plt

# %%
from inferencia.task.person_reid.body_reid.body_reid_manager import BodyReidManager

# %% [markdown]
# # constant

# %%
model_name = "osnet_x0_25"
# vis_name = "BBOXVisualizer"

# %% [markdown]
# # path

# %%
image_path = '/workspace/data/person_image.png'

# %% [markdown]
# # model

# %%
model = BodyReidManager.get_model(model_name=model_name)
# Out:
# 2021/07/17 01:37:02.237    INFO
# ...
#  Initialize BodyReid-OSNet-OSNetX025
# ...
#  [OSNet  MainProcess - MainThread]

# %% [markdown]
# # data

# %%
image = cv2.imread(image_path)

# %% [markdown]
# # inference

# %%
# %time body_reid_results = model.inference(image)
# Out:
# CPU times: user 5.62 ms, sys: 372 µs, total: 5.99 ms
# Wall time: 4.67 ms

# %%
body_reid_results[0].feature
# Out:
# array([0.0000000e+00, 0.0000000e+00, 5.5348259e-01, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 9.7862326e-02,
#        0.0000000e+00, 0.0000000e+00, 9.9028748e-01, 1.0950549e+00,
#        0.0000000e+00, 0.0000000e+00, 2.6399596e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 6.8758911e-01, 0.0000000e+00,
#        1.0340849e+00, 3.4932724e-01, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        5.8800012e-01, 0.0000000e+00, 1.3855561e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 6.5192574e-01, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        2.1675719e-01, 0.0000000e+00, 1.1224928e+00, 6.2549156e-01,
#        0.0000000e+00, 0.0000000e+00, 1.9838234e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 1.4944133e+00, 1.3076687e-01,
# ...
