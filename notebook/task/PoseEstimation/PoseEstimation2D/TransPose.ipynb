# %% [markdown]
# # import

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
from inferencia.task.pose_estimation.pose_estimation_2d.model.model.trans_pose.trans_pose_model import TransPoseModel
from inferencia.task.pose_estimation.pose_estimation_2d.pose_estimation_2d_manager import PoseEstimation2DManager

# %% [markdown]
# # data

# %%
image = cv2.imread('/workspace/data/person_image.png')

# %%
model_path = '/workspace/notebook/task/PoseEstimation/PoseEstimation2D/transpose.onnx'

# %% [markdown]
# # model

# %%
vis = PoseEstimation2DManager.get_visualizer()
model = PoseEstimation2DManager.get_model(model_name="TransPose", model_path=model_path)

# %% [markdown]
# # inference

# %%
# %%time
pose_rets = model.inference(image)
# Out:
# CPU times: user 278 ms, sys: 139 ms, total: 417 ms
# Wall time: 616 ms

# %% [markdown]
# # visualize

# %%
vis_img = vis.visualize(image, pose_rets[0].pose)

# %%
plt.figure(figsize=(8,6))
plt.imshow(vis_img[:,:,::-1])
plt.show()

# %%
from inferencia.task.pose_estimation.pose_estimation_2d.visualization.visualization.visualize_attention_map import inspect_atten_map_by_locations

# %%
pose_ret = pose_rets[0]

# %%
pose_ret
# Out:
# PoseEstimation2dResult(pose=array([[7.49242630e+01, 4.49164009e+01, 9.76155043e-01],
#        [8.14985962e+01, 3.28990211e+01, 9.36308265e-01],
#        [6.74566116e+01, 3.48365402e+01, 9.85072076e-01],
#        [8.93732300e+01, 4.48404503e+01, 9.15564775e-01],
#        [5.69211388e+01, 4.40825539e+01, 9.21416998e-01],
#        [9.35608444e+01, 1.02076569e+02, 7.86690652e-01],
#        [5.06506691e+01, 9.61579208e+01, 7.94260085e-01],
#        [1.10804100e+02, 1.15429115e+02, 2.80373275e-01],
#        [4.71726894e+00, 1.32106522e+02, 6.26699388e-01],
#        [1.11808174e+02, 1.49177475e+02, 2.79961765e-01],
#        [4.02773819e+01, 1.84297882e+02, 8.73965323e-01],
#        [8.07846069e+01, 2.37926254e+02, 6.16323769e-01],
#        [4.90187836e+01, 2.20754227e+02, 5.90317309e-01],
#        [5.96122437e+01, 3.05672333e+02, 5.86028576e-01],
#        [8.36319580e+01, 3.05812225e+02, 8.75409961e-01],
#        [4.80008354e+01, 4.09063934e+02, 8.45010698e-01],
# ...

# %%
inspect_atten_map_by_locations(image, 
                               model, 
                               pose_ret.query_location, 
                               model_name="transposer", 
                               mode='dependency', 
                               save_img=True, 
                               threshold=0.01)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_476/4030865374.py in <module>
#       5                                mode='dependency',
#       6                                save_img=True,
# ----> 7                                threshold=0.01)
#
# /workspace/inferencia/task/pose_estimation/pose_estimation_2d/visualization/visualization/visualize_attention_map.py in inspect_atten_map_by_locations(image, model, query_locations, model_name, mode, threshold, device, kpt_color, img_name, save_img)
#     150
#     151     assert mode in ["dependency", "affect"]
# --> 152     inputs = torch.cat([image.to(device)]).unsqueeze(0)
#     153     features = []
#     154     global_enc_atten_maps = []
#
# AttributeError: 'numpy.ndarray' object has no attribute 'to'

# %%
import onnx

# %%
model = onnx.load(model_path)

# %%
model.red

# %%
import cv2

# %%
image = cv2.imread('/workspace/data/person_image.png')

# %%
# %%time
rets = model.inference(image)
# Out:
# ...
# (1, 17, 1)
# CPU times: user 37.3 ms, sys: 5.09 ms, total: 42.4 ms
# Wall time: 35.8 ms

# %%
rets
# Out:
# [PoseEstimation2dResult(pose=array([[ 74.924263  ,  44.91640091,   0.97615486],
#         [ 81.49860382,  32.89902115,   0.97615486],
#         [ 67.45661163,  34.83653641,   0.97615486],
#         [ 89.37322998,  44.8404541 ,   0.97615486],
#         [ 56.92113876,  44.08255386,   0.97615486],
#         [ 93.56084442, 102.07657623,   0.97615486],
#         [ 50.6506691 ,  96.15792084,   0.97615486],
#         [110.80410004, 115.42910004,   0.97615486],
#         [  4.71726894, 132.10652161,   0.97615486],
#         [111.80818939, 149.17747498,   0.97615486],
#         [ 40.2773819 , 184.29788208,   0.97615486],
#         [ 80.78460693, 237.92625427,   0.97615486],
#         [ 49.01878357, 220.75424194,   0.97615486],
#         [ 59.61223984, 305.67233276,   0.97615486],
#         [ 83.63195038, 305.81222534,   0.97615486],
#         [ 48.00082779, 409.06393433,   0.97615486],
# ...

# %%
import numpy as np

# %%
a = np.zeros(5)

# %%
a
# Out:
# array([0., 0., 0., 0., 0.])

# %%
a[np.newaxis].T
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        [0.],
#        [0.]])

# %%
a.reshape(-1)
# Out:
# array([0., 0., 0., 0., 0.])

# %%
np.array([[1,2,3,4,5]])
# Out:
# array([[1, 2, 3, 4, 5]])

# %%
rets
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_165/3502843354.py in <module>
# ----> 1 rets
#
# NameError: name 'rets' is not defined

# %%
in_b, in_c, in_h, in_w = model.sess.get_inputs()[0].shape
in_size = in_h, in_w

# %%
a.shape
# Out:
# [1, 3, 256, 192]
