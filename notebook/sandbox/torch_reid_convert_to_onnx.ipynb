# %% [markdown]
# # install

# %%
# !pip install torch
# !pip install torchvision==0.5.0
# !pip install scipy==1.4.1
# !pip install gdown
# !pip install tensorboard
# Out:
# Requirement already satisfied: torchvision==0.5.0 in /local/python-3.7.9/lib/python3.7/site-packages (0.5.0)
# Requirement already satisfied: six in /home/ubuntu/.local/lib/python3.7/site-packages (from torchvision==0.5.0) (1.16.0)
# Requirement already satisfied: numpy in /home/ubuntu/.local/lib/python3.7/site-packages (from torchvision==0.5.0) (1.21.0)
# Requirement already satisfied: torch==1.4.0 in /local/python-3.7.9/lib/python3.7/site-packages (from torchvision==0.5.0) (1.4.0)
# Requirement already satisfied: pillow>=4.1.1 in /home/ubuntu/.local/lib/python3.7/site-packages (from torchvision==0.5.0) (8.3.0)
# WARNING: You are using pip version 20.1.1; however, version 21.1.3 is available.
# You should consider upgrading via the '/local/python-3.7.9/bin/python3.7 -m pip install --upgrade pip' command.
# Requirement already satisfied: scipy==1.4.1 in /local/python-3.7.9/lib/python3.7/site-packages (1.4.1)
# Requirement already satisfied: numpy>=1.13.3 in /home/ubuntu/.local/lib/python3.7/site-packages (from scipy==1.4.1) (1.21.0)
# WARNING: You are using pip version 20.1.1; however, version 21.1.3 is available.
# You should consider upgrading via the '/local/python-3.7.9/bin/python3.7 -m pip install --upgrade pip' command.
# Requirement already satisfied: gdown in /local/python-3.7.9/lib/python3.7/site-packages (3.13.0)
# Requirement already satisfied: requests[socks]>=2.12.0 in /home/ubuntu/.local/lib/python3.7/site-packages (from gdown) (2.25.1)
# Requirement already satisfied: filelock in /local/python-3.7.9/lib/python3.7/site-packages (from gdown) (3.0.12)
# Requirement already satisfied: six in /home/ubuntu/.local/lib/python3.7/site-packages (from gdown) (1.16.0)
# Requirement already satisfied: tqdm in /local/python-3.7.9/lib/python3.7/site-packages (from gdown) (4.61.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ubuntu/.local/lib/python3.7/site-packages (from requests[socks]>=2.12.0->gdown) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ubuntu/.local/lib/python3.7/site-packages (from requests[socks]>=2.12.0->gdown) (1.26.6)
# Requirement already satisfied: idna<3,>=2.5 in /home/ubuntu/.local/lib/python3.7/site-packages (from requests[socks]>=2.12.0->gdown) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/ubuntu/.local/lib/python3.7/site-packages (from requests[socks]>=2.12.0->gdown) (4.0.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in /local/python-3.7.9/lib/python3.7/site-packages (from requests[socks]>=2.12.0->gdown) (1.7.1)
# WARNING: You are using pip version 20.1.1; however, version 21.1.3 is available.
# You should consider upgrading via the '/local/python-3.7.9/bin/python3.7 -m pip install --upgrade pip' command.
# Requirement already satisfied: tensorboard in /local/python-3.7.9/lib/python3.7/site-packages (2.5.0)
# Requirement already satisfied: grpcio>=1.24.3 in /local/python-3.7.9/lib/python3.7/site-packages (from tensorboard) (1.38.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /local/python-3.7.9/lib/python3.7/site-packages (from tensorboard) (1.8.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /local/python-3.7.9/lib/python3.7/site-packages (from tensorboard) (0.6.1)
# Requirement already satisfied: setuptools>=41.0.0 in /local/python-3.7.9/lib/python3.7/site-packages (from tensorboard) (47.1.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /local/python-3.7.9/lib/python3.7/site-packages (from tensorboard) (2.0.1)
# Requirement already satisfied: protobuf>=3.6.0 in /home/ubuntu/.local/lib/python3.7/site-packages (from tensorboard) (3.17.3)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /local/python-3.7.9/lib/python3.7/site-packages (from tensorboard) (0.36.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /local/python-3.7.9/lib/python3.7/site-packages (from tensorboard) (0.4.4)
# Requirement already satisfied: numpy>=1.12.0 in /home/ubuntu/.local/lib/python3.7/site-packages (from tensorboard) (1.21.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/ubuntu/.local/lib/python3.7/site-packages (from tensorboard) (2.25.1)
# Requirement already satisfied: absl-py>=0.4 in /local/python-3.7.9/lib/python3.7/site-packages (from tensorboard) (0.13.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /local/python-3.7.9/lib/python3.7/site-packages (from tensorboard) (1.32.1)
# Requirement already satisfied: markdown>=2.6.8 in /local/python-3.7.9/lib/python3.7/site-packages (from tensorboard) (3.3.4)
# Requirement already satisfied: six>=1.5.2 in /home/ubuntu/.local/lib/python3.7/site-packages (from grpcio>=1.24.3->tensorboard) (1.16.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /local/python-3.7.9/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard) (1.3.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/ubuntu/.local/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ubuntu/.local/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /home/ubuntu/.local/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ubuntu/.local/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard) (1.26.6)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /local/python-3.7.9/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /local/python-3.7.9/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /local/python-3.7.9/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard) (0.2.8)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /home/ubuntu/.local/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard) (3.10.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /local/python-3.7.9/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard) (3.1.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /local/python-3.7.9/lib/python3.7/site-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard) (0.4.8)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /home/ubuntu/.local/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard) (3.10.0.0)
# Requirement already satisfied: zipp>=0.5 in /home/ubuntu/.local/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard) (3.5.0)
# WARNING: You are using pip version 20.1.1; however, version 21.1.3 is available.
# You should consider upgrading via the '/local/python-3.7.9/bin/python3.7 -m pip install --upgrade pip' command.

# %% [markdown]
# # import

# %%
import numpy as np
from PIL.Image import fromarray

import torch
import torchreid
from torchreid.data.transforms import build_transforms
# Out:
# /workspace/notebook/sandbox/deep-person-reid/torchreid/metrics/rank.py:12: UserWarning: Cython evaluation (very fast so highly recommended) is unavailable, now use python evaluation.
#   'Cython evaluation (very fast so highly recommended) is '

# %%
class BaseModel():
    height = 256
    width = 128
    
    def __init__(self, name='osnet_x1_0'):
    # def __init__(self, name='osnet_ain_x1_0'):
        self.name = name
        self._set_model(name)
        self._set_transformer()

    def _set_model(self, name):
        model = torchreid.models.build_model(
            name=name, # This can be:  'osnet_x1_0', 'osnet_x0_75', 'osnet_x0_25', 'resnet18'
            num_classes=751,
            pretrained=True
        )
        model = model.cuda()
        self.reid_model = model.eval()
    
    def _set_transformer(self):
        _, self.transformer = build_transforms(
                self.height,
                self.width,)
    
    def compute(self, images):
        images = self._validate(images)
        transformed_images = self._pre_process(images)
        results = self._inference(transformed_images)
        outputs = self._post_process(results)
        return outputs
    
    def _validate(self, images):
        if isinstance(images, list):
            pass

        elif isinstance(images, np.ndarray):
            images = [images]
        
        else:
            raise ValueError
        return images
        

    def _pre_process(self, images):
        transformed_images = []
        for image in images:
            image = fromarray(image)
            transformed_image = self.transformer(image)
            transformed_image = transformed_image.reshape(1, 3, self.height, self.width)
            transformed_images.append(transformed_image)
        transformed_images = torch.cat(transformed_images).cuda()
        return transformed_images
        
    def _inference(self, images):
        results = self.reid_model(images)
        return results

    def _post_process(self, results):
        outputs = results.cpu().detach().numpy()
        return outputs

# %%
model_name = "osnet_x0_25"
model = torchreid.models.build_model(
    name=model_name, # This can be:  'osnet_x1_0', 'osnet_x0_75', 'osnet_x0_25', 'resnet18'
    num_classes=1000,
    pretrained=True
)
# Out:
# Successfully loaded imagenet pretrained weights from "/home/ubuntu/.cache/torch/checkpoints/osnet_x0_25_imagenet.pth"

# %%
model.eval()
# Out:
# OSNet(
#   (conv1): ConvLayer(
#     (conv): Conv2d(3, 16, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#   )
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (conv2): Sequential(
#     (0): OSBlock(
#       (conv1): Conv1x1(
#         (conv): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv2a): LightConv3x3(
#         (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#         (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv2b): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv2c): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): LightConv3x3(
#           (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv2d): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): LightConv3x3(
#           (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): LightConv3x3(
#           (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (gate): ChannelGate(
#         (global_avgpool): AdaptiveAvgPool2d(output_size=1)
#         (fc1): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#         (fc2): Conv2d(1, 16, kernel_size=(1, 1), stride=(1, 1))
#         (gate_activation): Sigmoid()
#       )
#       (conv3): Conv1x1Linear(
#         (conv): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (downsample): Conv1x1Linear(
#         (conv): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): OSBlock(
#       (conv1): Conv1x1(
#         (conv): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv2a): LightConv3x3(
#         (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#         (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv2b): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv2c): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): LightConv3x3(
#           (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv2d): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): LightConv3x3(
#           (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): LightConv3x3(
#           (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (gate): ChannelGate(
#         (global_avgpool): AdaptiveAvgPool2d(output_size=1)
#         (fc1): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#         (fc2): Conv2d(1, 16, kernel_size=(1, 1), stride=(1, 1))
#         (gate_activation): Sigmoid()
#       )
#       (conv3): Conv1x1Linear(
#         (conv): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): Sequential(
#       (0): Conv1x1(
#         (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (1): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#   )
#   (conv3): Sequential(
#     (0): OSBlock(
#       (conv1): Conv1x1(
#         (conv): Conv2d(64, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv2a): LightConv3x3(
#         (conv1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#         (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv2b): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv2c): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): LightConv3x3(
#           (conv1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv2d): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): LightConv3x3(
#           (conv1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): LightConv3x3(
#           (conv1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (gate): ChannelGate(
#         (global_avgpool): AdaptiveAvgPool2d(output_size=1)
#         (fc1): Conv2d(24, 1, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#         (fc2): Conv2d(1, 24, kernel_size=(1, 1), stride=(1, 1))
#         (gate_activation): Sigmoid()
#       )
#       (conv3): Conv1x1Linear(
#         (conv): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (downsample): Conv1x1Linear(
#         (conv): Conv2d(64, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): OSBlock(
#       (conv1): Conv1x1(
#         (conv): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv2a): LightConv3x3(
#         (conv1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#         (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv2b): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv2c): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): LightConv3x3(
#           (conv1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv2d): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): LightConv3x3(
#           (conv1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): LightConv3x3(
#           (conv1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (gate): ChannelGate(
#         (global_avgpool): AdaptiveAvgPool2d(output_size=1)
#         (fc1): Conv2d(24, 1, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#         (fc2): Conv2d(1, 24, kernel_size=(1, 1), stride=(1, 1))
#         (gate_activation): Sigmoid()
#       )
#       (conv3): Conv1x1Linear(
#         (conv): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): Sequential(
#       (0): Conv1x1(
#         (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (1): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#   )
#   (conv4): Sequential(
#     (0): OSBlock(
#       (conv1): Conv1x1(
#         (conv): Conv2d(96, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv2a): LightConv3x3(
#         (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv2b): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv2c): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): LightConv3x3(
#           (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv2d): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): LightConv3x3(
#           (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): LightConv3x3(
#           (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (gate): ChannelGate(
#         (global_avgpool): AdaptiveAvgPool2d(output_size=1)
#         (fc1): Conv2d(32, 2, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#         (fc2): Conv2d(2, 32, kernel_size=(1, 1), stride=(1, 1))
#         (gate_activation): Sigmoid()
#       )
#       (conv3): Conv1x1Linear(
#         (conv): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (downsample): Conv1x1Linear(
#         (conv): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): OSBlock(
#       (conv1): Conv1x1(
#         (conv): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv2a): LightConv3x3(
#         (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv2b): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv2c): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): LightConv3x3(
#           (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv2d): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): LightConv3x3(
#           (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): LightConv3x3(
#           (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (gate): ChannelGate(
#         (global_avgpool): AdaptiveAvgPool2d(output_size=1)
#         (fc1): Conv2d(32, 2, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#         (fc2): Conv2d(2, 32, kernel_size=(1, 1), stride=(1, 1))
#         (gate_activation): Sigmoid()
#       )
#       (conv3): Conv1x1Linear(
#         (conv): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (conv5): Conv1x1(
#     (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#   )
#   (global_avgpool): AdaptiveAvgPool2d(output_size=1)
#   (fc): Sequential(
#     (0): Linear(in_features=128, out_features=512, bias=True)
#     (1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (classifier): Linear(in_features=512, out_features=1000, bias=True)
# )

# %% [markdown]
# # convert

# %%
import torch.onnx

# %%
batch_size = 3
height = 256
width = 128

# %%
x = torch.randn(batch_size, 3, height, width, requires_grad=True)

# %%
torch_out = model(x)

# %%
model_save_path = "{}.onnx".format(model_name)

# %%
convert = False
if convert:
    torch.onnx.export(model,               # model being run
                      x,                         # model input (or a tuple for multiple inputs)
                      model_save_path,   # where to save the model (can be a file or file-like object)
                      export_params=True,        # store the trained parameter weights inside the model file
                      opset_version=10,          # the ONNX version to export the model to
                      do_constant_folding=True,  # whether to execute constant folding for optimization
                      input_names = ['input'],   # the model's input names
                      output_names = ['output'], # the model's output names
                      dynamic_axes={'input' : {0 : 'batch_size'},    # variable length axes
                                    'output' : {0 : 'batch_size'}})

# %% [markdown]
# # onnx

# %%
import onnx

onnx_model = onnx.load(model_save_path)
onnx.checker.check_model(onnx_model)

# %%
import onnxruntime

sess = onnxruntime.InferenceSession(model_save_path)

def to_numpy(tensor):
    return tensor.detach().cpu().numpy() if tensor.requires_grad else tensor.cpu().numpy()

# compute ONNX Runtime output prediction
ort_inputs = {sess.get_inputs()[0].name: to_numpy(x)}
ort_outs = sess.run(None, ort_inputs)

# %%
ort_outs
# Out:
# [array([[0.        , 0.        , 0.        , ..., 0.        , 0.48593774,
#          0.        ],
#         [0.        , 0.        , 0.        , ..., 0.        , 0.26337618,
#          0.        ],
#         [0.        , 0.        , 0.        , ..., 0.        , 0.84350514,
#          0.        ]], dtype=float32)]

# %%
# compare ONNX Runtime and PyTorch results
np.testing.assert_allclose(to_numpy(torch_out), 
                           ort_outs[0], 
                           rtol=1e-03, 
                           atol=1e-05)

print("Exported model has been tested with ONNXRuntime, and the result looks good!")
# Out:
# Exported model has been tested with ONNXRuntime, and the result looks good!

# %% [markdown]
# # pre process

# %% [markdown]
# ## constant

# %%
norm_mean = np.array([0.485, 0.456, 0.406])
norm_std = np.array([0.229, 0.224, 0.225])

# %% [markdown]
# ## data

# %%
import cv2

# %%
img = cv2.imread('/workspace/data/dog.jpg')
# img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
# img = cv2.resize(img, (height, width), cv2.INTER_LINEAR)

# %% [markdown]
# ## torch

# %%
from torchvision.transforms import (
    Resize, Compose, ToTensor, Normalize, ColorJitter, RandomHorizontalFlip, CenterCrop
)

# %%
height = 256
width = 128
normalize = Normalize(mean=norm_mean, std=norm_std)

# %%
transform = Compose([
        Resize((height, width)),
        ToTensor(),
        normalize,
    ])

# %%
transform
# Out:
# Compose(
#     Resize(size=(256, 128), interpolation=PIL.Image.BILINEAR)
#     ToTensor()
#     Normalize(mean=[0.485 0.456 0.406], std=[0.229 0.224 0.225])
# )

# %%
from PIL import Image

# %%
img_pil = Image.fromarray(img)

# %%
trns_img = transform(img_pil)

# %%
resize = Resize((height, width))

# %%
trns_rsz_img = np.asarray(resize(img_pil))
trns_rsz_img
# Out:
# array([[[ 53,  61,  60],
#         [ 51,  59,  58],
#         [ 52,  60,  59],
#         ...,
#         [162, 189, 174],
#         [157, 218, 205],
#         [ 92, 157, 152]],
#
#        [[ 53,  61,  60],
#         [ 53,  61,  60],
#         [ 53,  61,  60],
#         ...,
#         [148, 195, 166],
#         [138, 213, 182],
#         [ 84, 141, 134]],
#
#        [[ 53,  61,  60],
#         [ 53,  61,  60],
#         [ 53,  61,  60],
#         ...,
#         [159, 224, 204],
#         [132, 215, 182],
#         [ 80, 128, 121]],
#
#        ...,
#
#        [[175, 164, 157],
#         [174, 163, 157],
#         [177, 166, 159],
#         ...,
#         [121, 127, 126],
#         [122, 127, 127],
#         [104, 109, 115]],
#
#        [[177, 166, 158],
#         [176, 165, 157],
#         [177, 165, 158],
#         ...,
#         [122, 128, 127],
#         [121, 127, 127],
#         [ 93,  96, 106]],
#
#        [[175, 165, 156],
#         [176, 165, 157],
#         [175, 164, 156],
#         ...,
#         [122, 128, 127],
#         [121, 126, 127],
#         [ 86,  88,  99]]], dtype=uint8)

# %%
np.array(trns_img)[0][0]
# Out:
# array([-1.2102921 , -1.2445416 , -1.2274169 , -1.2102921 , -1.2102921 ,
#        -1.1589178 , -0.5424266 , -0.6451751 , -0.31980482, -0.08005828,
#        -0.25130582, -0.19993155, -0.6622999 , -0.5424266 , -0.33692956,
#        -0.55955136, -0.2855553 , -0.49105233, -0.43967807,  0.38231018,
#        -0.04580877, -0.18280679, -0.57667613, -0.5424266 ,  0.07406463,
#        -0.14855729, -0.23418105, -0.23418105, -0.45680285, -0.18280679,
#        -0.35405433,  0.5535577 ,  0.15968838, -0.04580877,  0.10831413,
#        -0.14855729,  0.02269024, -0.2855553 , -0.4739276 , -0.8506721 ,
#        -0.57667613, -0.30268008,  0.00556549, -0.38830382, -0.79929787,
#        -0.9362959 , -0.8677969 , -0.4739276 , -0.8335474 , -0.04580877,
#        -0.18280679, -0.49105233, -0.81642264,  0.4850587 ,  0.72480524,
#         0.15968838, -0.16568205, -0.37117907, -1.1589178 , -1.0904187 ,
#        -1.2102921 , -1.1760426 , -1.0904187 , -1.3130406 , -1.3130406 ,
#        -1.2445416 , -1.2616663 , -1.2102921 , -1.2274169 , -1.1931673 ,
#        -1.073294  , -1.141793  , -1.5527872 , -1.0904187 ,  0.24531215,
#         0.41655967, -0.37117907,  0.5535577 ,  0.2966864 , -0.38830382,
#        -1.004795  , -1.1931673 , -1.0904187 , -1.1075436 , -1.2102921 ,
#        -1.2102921 , -1.3130406 , -1.1075436 , -1.3301654 , -1.1075436 ,
#        -1.4329139 , -1.2102921 , -0.88492167, -0.95342064, -0.7307989 ,
#        -0.9362959 , -0.13143253,  0.17681314,  0.3651854 , -0.2170563 ,
#        -0.55955136, -0.4054286 , -0.59380084, -0.6451751 , -0.55955136,
#        -0.6280504 , -0.95342064, -1.3472902 , -1.4842881 , -1.5527872 ,
#        -1.5014129 , -1.5014129 , -1.5527872 , -1.6384109 , -1.6041614 ,
#        -1.5699118 , -1.2787911 , -1.6041614 , -1.5870366 , -1.5185376 ,
#        -1.5185376 , -0.9876702 , -0.6451751 , -1.5699118 , -1.3472902 ,
#         0.6563062 ,  0.57068247, -0.5424266 ], dtype=float32)

# %%
trns_img.shape
trns_img[0]
# Out:
# tensor([[-1.2103, -1.2445, -1.2274,  ...,  0.6563,  0.5707, -0.5424],
#         [-1.2103, -1.2103, -1.2103,  ...,  0.4166,  0.2453, -0.6794],
#         [-1.2103, -1.2103, -1.2103,  ...,  0.6049,  0.1426, -0.7479],
#         ...,
#         [ 0.8789,  0.8618,  0.9132,  ..., -0.0458, -0.0287, -0.3369],
#         [ 0.9132,  0.8961,  0.9132,  ..., -0.0287, -0.0458, -0.5253],
#         [ 0.8789,  0.8961,  0.8789,  ..., -0.0287, -0.0458, -0.6452]])

# %%
def resize_compatibility_with_torchvision(img,
                                          height, 
                                          width):
    img_pil = Image.fromarray(img)
    img_resize = img_pil.resize((width, height), 
                                resample=Image.BILINEAR)
    img_resize = np.asarray(img_resize)
    return img_resize

# %%
def normalize_compatibility_with_torchvision(img,
                                          norm_mean=np.array([0.485, 0.456, 0.406]),
                                          norm_std=np.array([0.229, 0.224, 0.225])):
    img_resize = (img - 255 * norm_mean) / (255 * norm_std)
    img_resize = img_resize.transpose(2,0,1)
    img_resize = img_resize.astype(np.float32)
    return img_resize

# %%
rsz_img = resize_compatibility_with_torchvision(img, height, width)

# %%
norm_img = normalize_compatibility_with_torchvision(rsz_img)

# %%
trns_rsz_img[0]
# Out:
# array([[ 53,  61,  60],
#        [ 51,  59,  58],
#        [ 52,  60,  59],
#        [ 53,  61,  60],
#        [ 53,  64,  62],
#        [ 56,  67,  66],
#        [ 92, 135, 128],
#        [ 86, 154, 141],
#        [105, 177, 153],
#        [119, 187, 155],
#        [109, 163, 146],
#        [112, 158, 149],
#        [ 85, 146, 123],
#        [ 92, 133, 121],
#        [104, 149, 139],
#        [ 91, 151, 135],
#        [107, 157, 148],
#        [ 95, 135, 121],
#        [ 98, 145, 139],
#        [146, 179, 191],
#        [121, 179, 177],
#        [113, 180, 165],
#        [ 90, 150, 129],
#        [ 92, 142, 135],
#        [128, 177, 172],
#        [115, 166, 168],
#        [110, 185, 154],
#        [110, 183, 150],
#        [ 97, 193, 156],
#        [113, 213, 180],
#        [103, 202, 168],
#        [156, 235, 207],
#        [133, 227, 193],
#        [121, 214, 186],
#        [130, 216, 191],
#        [115, 191, 166],
#        [125, 188, 171],
#        [107, 184, 156],
#        [ 96, 171, 135],
#        [ 74, 125, 113],
#        [ 90, 133, 136],
#        [106, 162, 158],
#        [124, 173, 180],
#        [101, 180, 164],
#        [ 77, 200, 150],
#        [ 69, 190, 133],
#        [ 73, 166, 125],
#        [ 96, 182, 143],
#        [ 75, 170, 141],
#        [121, 210, 176],
#        [113, 210, 168],
#        [ 95, 164, 141],
#        [ 76, 157, 139],
#        [152, 204, 192],
#        [166, 232, 212],
#        [133, 216, 183],
#        [114, 217, 170],
#        [102, 197, 153],
#        [ 56, 134,  96],
#        [ 60, 133, 104],
#        [ 53, 120,  84],
#        [ 55, 116,  91],
#        [ 60, 113, 102],
#        [ 47, 121,  90],
#        [ 47, 131,  97],
#        [ 51, 130,  96],
#        [ 50, 127,  90],
#        [ 53, 132,  97],
#        [ 52, 139, 101],
#        [ 54, 136,  92],
#        [ 61, 139, 101],
#        [ 57, 145, 103],
#        [ 33, 143,  89],
#        [ 60, 182, 130],
#        [138, 238, 202],
#        [148, 228, 200],
#        [102, 202, 162],
#        [156, 237, 204],
#        [141, 228, 194],
#        [101, 212, 179],
#        [ 65, 159, 130],
#        [ 54, 119,  95],
#        [ 60, 118,  98],
#        [ 59, 124,  99],
#        [ 53, 120,  90],
#        [ 53, 120,  91],
#        [ 47, 112,  82],
#        [ 59, 117,  98],
#        [ 46, 115,  88],
#        [ 59, 121,  94],
#        [ 40, 100,  78],
#        [ 53, 101,  86],
#        [ 72, 127, 110],
#        [ 68, 136, 116],
#        [ 81, 159, 135],
#        [ 69, 135, 122],
#        [116, 181, 173],
#        [134, 212, 188],
#        [145, 207, 199],
#        [111, 185, 180],
#        [ 91, 176, 165],
#        [100, 170, 139],
#        [ 89, 142, 120],
#        [ 86, 140, 128],
#        [ 91, 150, 140],
#        [ 87, 146, 126],
#        [ 68, 133, 111],
#        [ 45,  97,  76],
#        [ 37,  85,  68],
#        [ 33,  78,  64],
#        [ 36,  80,  66],
#        [ 36,  74,  61],
#        [ 33,  83,  62],
#        [ 28,  73,  53],
#        [ 30,  66,  54],
#        [ 32,  66,  55],
#        [ 49,  98,  78],
#        [ 30,  69,  55],
#        [ 31,  81,  62],
#        [ 35,  84,  70],
#        [ 35,  85,  63],
#        [ 66, 126, 104],
#        [ 86, 145, 130],
#        [ 32,  83,  64],
#        [ 45,  98,  77],
#        [162, 189, 174],
#        [157, 218, 205],
#        [ 92, 157, 152]], dtype=uint8)

# %%
rsz_img[0]
# Out:
# array([[ 53,  61,  60],
#        [ 51,  59,  58],
#        [ 52,  60,  59],
#        [ 53,  61,  60],
#        [ 53,  64,  62],
#        [ 56,  67,  66],
#        [ 92, 135, 128],
#        [ 86, 154, 141],
#        [105, 177, 153],
#        [119, 187, 155],
#        [109, 163, 146],
#        [112, 158, 149],
#        [ 85, 146, 123],
#        [ 92, 133, 121],
#        [104, 149, 139],
#        [ 91, 151, 135],
#        [107, 157, 148],
#        [ 95, 135, 121],
#        [ 98, 145, 139],
#        [146, 179, 191],
#        [121, 179, 177],
#        [113, 180, 165],
#        [ 90, 150, 129],
#        [ 92, 142, 135],
#        [128, 177, 172],
#        [115, 166, 168],
#        [110, 185, 154],
#        [110, 183, 150],
#        [ 97, 193, 156],
#        [113, 213, 180],
#        [103, 202, 168],
#        [156, 235, 207],
#        [133, 227, 193],
#        [121, 214, 186],
#        [130, 216, 191],
#        [115, 191, 166],
#        [125, 188, 171],
#        [107, 184, 156],
#        [ 96, 171, 135],
#        [ 74, 125, 113],
#        [ 90, 133, 136],
#        [106, 162, 158],
#        [124, 173, 180],
#        [101, 180, 164],
#        [ 77, 200, 150],
#        [ 69, 190, 133],
#        [ 73, 166, 125],
#        [ 96, 182, 143],
#        [ 75, 170, 141],
#        [121, 210, 176],
#        [113, 210, 168],
#        [ 95, 164, 141],
#        [ 76, 157, 139],
#        [152, 204, 192],
#        [166, 232, 212],
#        [133, 216, 183],
#        [114, 217, 170],
#        [102, 197, 153],
#        [ 56, 134,  96],
#        [ 60, 133, 104],
#        [ 53, 120,  84],
#        [ 55, 116,  91],
#        [ 60, 113, 102],
#        [ 47, 121,  90],
#        [ 47, 131,  97],
#        [ 51, 130,  96],
#        [ 50, 127,  90],
#        [ 53, 132,  97],
#        [ 52, 139, 101],
#        [ 54, 136,  92],
#        [ 61, 139, 101],
#        [ 57, 145, 103],
#        [ 33, 143,  89],
#        [ 60, 182, 130],
#        [138, 238, 202],
#        [148, 228, 200],
#        [102, 202, 162],
#        [156, 237, 204],
#        [141, 228, 194],
#        [101, 212, 179],
#        [ 65, 159, 130],
#        [ 54, 119,  95],
#        [ 60, 118,  98],
#        [ 59, 124,  99],
#        [ 53, 120,  90],
#        [ 53, 120,  91],
#        [ 47, 112,  82],
#        [ 59, 117,  98],
#        [ 46, 115,  88],
#        [ 59, 121,  94],
#        [ 40, 100,  78],
#        [ 53, 101,  86],
#        [ 72, 127, 110],
#        [ 68, 136, 116],
#        [ 81, 159, 135],
#        [ 69, 135, 122],
#        [116, 181, 173],
#        [134, 212, 188],
#        [145, 207, 199],
#        [111, 185, 180],
#        [ 91, 176, 165],
#        [100, 170, 139],
#        [ 89, 142, 120],
#        [ 86, 140, 128],
#        [ 91, 150, 140],
#        [ 87, 146, 126],
#        [ 68, 133, 111],
#        [ 45,  97,  76],
#        [ 37,  85,  68],
#        [ 33,  78,  64],
#        [ 36,  80,  66],
#        [ 36,  74,  61],
#        [ 33,  83,  62],
#        [ 28,  73,  53],
#        [ 30,  66,  54],
#        [ 32,  66,  55],
#        [ 49,  98,  78],
#        [ 30,  69,  55],
#        [ 31,  81,  62],
#        [ 35,  84,  70],
#        [ 35,  85,  63],
#        [ 66, 126, 104],
#        [ 86, 145, 130],
#        [ 32,  83,  64],
#        [ 45,  98,  77],
#        [162, 189, 174],
#        [157, 218, 205],
#        [ 92, 157, 152]], dtype=uint8)

# %%
trns_rsz_img

# %%
np.testing.assert_allclose(trns_rsz_img, 
                           rsz_img, 
                           rtol=1e-03, 
                           atol=1e-05)

# %%
trns_rsz_img

# %%
img_resize[0]
# Out:
# array([[-1.210292  , -1.2445415 , -1.2274168 , ...,  0.6563062 ,
#          0.5706824 , -0.5424266 ],
#        [-1.210292  , -1.210292  , -1.210292  , ...,  0.41655964,
#          0.2453121 , -0.6794246 ],
#        [-1.210292  , -1.210292  , -1.210292  , ...,  0.60493195,
#          0.14256358, -0.7479236 ],
#        ...,
#        [ 0.878928  ,  0.86180323,  0.9131775 , ..., -0.04580872,
#         -0.02868396, -0.33692953],
#        [ 0.9131775 ,  0.8960527 ,  0.9131775 , ..., -0.02868396,
#         -0.04580872, -0.5253018 ],
#        [ 0.878928  ,  0.8960527 ,  0.878928  , ..., -0.02868396,
#         -0.04580872, -0.6451751 ]], dtype=float32)

# %%
np.testing()
# Out:
# <module 'numpy.testing' from '/home/ubuntu/.local/lib/python3.7/site-packages/numpy/testing/__init__.py'>

# %%
norm_img_numpy_trans[0]
# Out:
# array([[-1.24454148, -1.19316722, -1.22741673, ..., -0.08005822,
#          0.31381111, -1.33016525],
#        [-1.21029198, -1.17604247, -1.17604247, ..., -0.1999315 ,
#         -0.04580872, -1.29591575],
#        [-1.22741673, -1.19316722, -1.17604247, ..., -1.5356623 ,
#         -1.33016525, -1.46716328],
#        ...,
#        [ 0.89605274,  0.96455176,  1.01592602, ..., -0.02868396,
#         -0.02868396, -0.06293347],
#        [ 0.96455176,  0.84467848,  0.94742701, ..., -0.04580872,
#         -0.02868396, -0.57667609],
#        [ 0.94742701,  0.84467848,  0.86180324, ..., -0.01155921,
#         -0.04580872, -1.50141279]])

# %%
x = torch.randn(batch_size, 3, height, width, requires_grad=True)

# %%
x.sub_(torch.to(norm_mean))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_185/801342217.py in <module>
# ----> 1 x.sub_(norm_mean)
#
# TypeError: sub_(): argument 'other' (position 1) must be Tensor, not numpy.ndarray

# %%
# from torchreid.data.transforms import build_transforms

# _, transformer = build_transforms(
#                 height,
#                 width,)

# transformer

# trns_img_torchreid = transformer(img_pil)

# trns_img[0]

# trns_img_torchreid[0]

# %% [markdown]
# ## numpy

# %%
norm_mean = np.array([0.4914, 0.4822, 0.4465])
norm_std = np.array([0.229, 0.224, 0.225],)

# %%
norm_img_numpy = (img - 255 * norm_mean) / (255 * norm_std)
norm_img_numpy[0]
# Out:
# array([[-1.28961384, -1.13727241, -0.99098039],
#        [-1.27248908, -1.11976541, -0.9735512 ],
#        [-1.23823958, -1.0847514 , -0.93869281],
#        ...,
#        [-1.3409881 , -0.59455532,  0.49050109],
#        [-1.44373662, -1.27732843, -0.45067538],
#        [-1.3409881 , -0.90968137, -0.88640523]])

# %%
img.shape
# Out:
# (576, 768, 3)

# %%
img
# Out:
# array([[[ 50,  58,  57],
#         [ 51,  59,  58],
#         [ 53,  61,  60],
#         ...,
#         [ 47,  89, 142],
#         [ 41,  50,  88],
#         [ 47,  71,  63]],
#
#        [[ 51,  59,  58],
#         [ 51,  59,  58],
#         [ 52,  60,  59],
#         ...,
#         [ 37,  74, 124],
#         [ 41,  50,  84],
#         [ 46,  70,  58]],
#
#        [[ 51,  59,  58],
#         [ 51,  59,  58],
#         [ 52,  60,  59],
#         ...,
#         [ 25,  54,  98],
#         [ 48,  54,  77],
#         [ 43,  62,  45]],
#
#        ...,
#
#        [[179, 168, 160],
#         [179, 168, 160],
#         [182, 171, 163],
#         ...,
#         [ 64,  64,  80],
#         [ 36,  39,  53],
#         [ 48,  53,  62]],
#
#        [[180, 169, 161],
#         [179, 168, 160],
#         [175, 164, 156],
#         ...,
#         [ 61,  61,  79],
#         [ 37,  40,  54],
#         [ 52,  56,  67]],
#
#        [[176, 165, 157],
#         [178, 167, 159],
#         [172, 161, 153],
#         ...,
#         [ 62,  62,  80],
#         [ 33,  36,  50],
#         [ 35,  39,  50]]], dtype=uint8)

# %%
x = np.zeros((3, 100, 100))

# %%
x.shape
# Out:
# (3, 100, 100)

# %%
x = x[np.newaxis]

# %%
x.shape
# Out:
# (1, 3, 100, 100)

# %%
# Export the model
torch.onnx.export(torch_model,               # model being run
                  x,                         # model input (or a tuple for multiple inputs)
                  "super_resolution.onnx",   # where to save the model (can be a file or file-like object)
                  export_params=True,        # store the trained parameter weights inside the model file
                  opset_version=10,          # the ONNX version to export the model to
                  do_constant_folding=True,  # whether to execute constant folding for optimization
                  input_names = ['input'],   # the model's input names
                  output_names = ['output'], # the model's output names
                  dynamic_axes={'input' : {0 : 'batch_size'},    # variable length axes
                                'output' : {0 : 'batch_size'}})

# %%
model.
# Out:
# OSNet(
#   (conv1): ConvLayer(
#     (conv): Conv2d(3, 16, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#   )
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (conv2): Sequential(
#     (0): OSBlock(
#       (conv1): Conv1x1(
#         (conv): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv2a): LightConv3x3(
#         (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#         (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv2b): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv2c): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): LightConv3x3(
#           (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv2d): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): LightConv3x3(
#           (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): LightConv3x3(
#           (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (gate): ChannelGate(
#         (global_avgpool): AdaptiveAvgPool2d(output_size=1)
#         (fc1): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#         (fc2): Conv2d(1, 16, kernel_size=(1, 1), stride=(1, 1))
#         (gate_activation): Sigmoid()
#       )
#       (conv3): Conv1x1Linear(
#         (conv): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (downsample): Conv1x1Linear(
#         (conv): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): OSBlock(
#       (conv1): Conv1x1(
#         (conv): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv2a): LightConv3x3(
#         (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#         (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv2b): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv2c): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): LightConv3x3(
#           (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv2d): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): LightConv3x3(
#           (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): LightConv3x3(
#           (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (gate): ChannelGate(
#         (global_avgpool): AdaptiveAvgPool2d(output_size=1)
#         (fc1): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#         (fc2): Conv2d(1, 16, kernel_size=(1, 1), stride=(1, 1))
#         (gate_activation): Sigmoid()
#       )
#       (conv3): Conv1x1Linear(
#         (conv): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): Sequential(
#       (0): Conv1x1(
#         (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (1): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#   )
#   (conv3): Sequential(
#     (0): OSBlock(
#       (conv1): Conv1x1(
#         (conv): Conv2d(64, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv2a): LightConv3x3(
#         (conv1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#         (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv2b): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv2c): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): LightConv3x3(
#           (conv1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv2d): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): LightConv3x3(
#           (conv1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): LightConv3x3(
#           (conv1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (gate): ChannelGate(
#         (global_avgpool): AdaptiveAvgPool2d(output_size=1)
#         (fc1): Conv2d(24, 1, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#         (fc2): Conv2d(1, 24, kernel_size=(1, 1), stride=(1, 1))
#         (gate_activation): Sigmoid()
#       )
#       (conv3): Conv1x1Linear(
#         (conv): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (downsample): Conv1x1Linear(
#         (conv): Conv2d(64, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): OSBlock(
#       (conv1): Conv1x1(
#         (conv): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv2a): LightConv3x3(
#         (conv1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#         (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv2b): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv2c): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): LightConv3x3(
#           (conv1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv2d): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): LightConv3x3(
#           (conv1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): LightConv3x3(
#           (conv1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (gate): ChannelGate(
#         (global_avgpool): AdaptiveAvgPool2d(output_size=1)
#         (fc1): Conv2d(24, 1, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#         (fc2): Conv2d(1, 24, kernel_size=(1, 1), stride=(1, 1))
#         (gate_activation): Sigmoid()
#       )
#       (conv3): Conv1x1Linear(
#         (conv): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): Sequential(
#       (0): Conv1x1(
#         (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (1): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#   )
#   (conv4): Sequential(
#     (0): OSBlock(
#       (conv1): Conv1x1(
#         (conv): Conv2d(96, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv2a): LightConv3x3(
#         (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv2b): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv2c): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): LightConv3x3(
#           (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv2d): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): LightConv3x3(
#           (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): LightConv3x3(
#           (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (gate): ChannelGate(
#         (global_avgpool): AdaptiveAvgPool2d(output_size=1)
#         (fc1): Conv2d(32, 2, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#         (fc2): Conv2d(2, 32, kernel_size=(1, 1), stride=(1, 1))
#         (gate_activation): Sigmoid()
#       )
#       (conv3): Conv1x1Linear(
#         (conv): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (downsample): Conv1x1Linear(
#         (conv): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): OSBlock(
#       (conv1): Conv1x1(
#         (conv): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv2a): LightConv3x3(
#         (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv2b): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv2c): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): LightConv3x3(
#           (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv2d): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): LightConv3x3(
#           (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): LightConv3x3(
#           (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (gate): ChannelGate(
#         (global_avgpool): AdaptiveAvgPool2d(output_size=1)
#         (fc1): Conv2d(32, 2, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#         (fc2): Conv2d(2, 32, kernel_size=(1, 1), stride=(1, 1))
#         (gate_activation): Sigmoid()
#       )
#       (conv3): Conv1x1Linear(
#         (conv): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (conv5): Conv1x1(
#     (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#   )
#   (global_avgpool): AdaptiveAvgPool2d(output_size=1)
#   (fc): Sequential(
#     (0): Linear(in_features=128, out_features=512, bias=True)
#     (1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (classifier): Linear(in_features=512, out_features=1000, bias=True)
# )
